# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
casa_cara = list(ds['price']).index(max(ds['price']))
direccion_cara = ds.loc[casa_cara, 'address']

print(f"La casa con dirección en {direccion_cara} es la más cara y su precio es de {max(ds['price'])} EUR.")
# Out:
# La casa con dirección en El Escorial es la más cara y su precio es de 8500000 EUR.

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
casa_barata = list(ds['price']).index(min(ds['price']))
direccion_barata = ds.loc[casa_barata, 'address']

print(f"La casa con dirección en {direccion_barata} es la más barata y su precio es de {min(ds['price'])} EUR.")
# Out:
# La casa con dirección en Parla es la más barata y su precio es de 0 EUR.

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
casa_grande = list(ds['surface']).index(max(ds['surface']))
direccion_grande = ds.loc[casa_grande, 'address']
casa_pequeña = list(ds['surface']).index(min(ds['surface']))
direccion_pequeña = ds.loc[casa_pequeña, 'address']

print(f"la casa más grande está ubicada en {direccion_grande} y su superficie es de {max(ds['surface'])} metros.")
print(f"la casa más pequeña está ubicada en {direccion_pequeña} y su superficie es de {min(ds['surface'])} metros.")
# Out:
# la casa más grande está ubicada en Sevilla la Nueva y su superficie es de 249000.0 metros.
# la casa más pequeña está ubicada en Calle Amparo,  Madrid Capital y su superficie es de 15.0 metros.

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
todas_poblaciones = ds.groupby('level5').count()
poblaciones = list(todas_poblaciones.index)

print(poblaciones)
# Out:
# [' Madrid Capital', 'Ajalvir', 'Alcalá de Henares', 'Alcobendas', 'Alcorcón', 'Aldea del Fresno', 'Algete', 'Alpedrete', 'Ambite', 'Anchuelo', 'Aranjuez', 'Arganda del Rey', 'Arroyomolinos (Madrid)', 'Batres', 'Becerril de la Sierra', 'Belmonte de Tajo', 'Boadilla del Monte', 'Braojos', 'Brea de Tajo', 'Brunete', 'Buitrago del Lozoya', 'Bustarviejo', 'Cabanillas de la Sierra', 'Cadalso de los Vidrios', 'Camarma de Esteruelas', 'Campo Real', 'Canencia', 'Carabaña', 'Casarrubuelos', 'Cenicientos', 'Cercedilla', 'Chapinería', 'Chinchón', 'Ciempozuelos', 'Cobeña', 'Collado Mediano', 'Collado Villalba', 'Colmenar Viejo', 'Colmenar de Oreja', 'Colmenar del Arroyo', 'Colmenarejo', 'Corpa', 'Coslada', 'Cubas de la Sagra', 'Daganzo de Arriba', 'El Atazar', 'El Berrueco', 'El Boalo - Cerceda – Mataelpino', 'El Escorial', 'El Molar (Madrid)', 'El Vellón', 'El Álamo', 'Estremera', 'Fresnedillas de la Oliva', 'Fresno de Torote', 'Fresno de Torote - Serracines', 'Fuenlabrada', 'Fuente El Saz de Ja
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
def buscar_NaN(datos):
    NAs = []

    for row in datos.itertuples():
        for col_idx, value in zip(datos.columns, row[1:]):
            if pd.isna(value):
                NAs.append(f"True:{row.Index},{col_idx}")

    return NAs 

print(buscar_NaN(ds))
# Out:
# ['True:0,level6', 'True:0,level8', 'True:0,zipCode', 'True:0,customZone', 'True:1,surface', 'True:1,level6', 'True:1,level8', 'True:1,zipCode', 'True:1,customZone', 'True:2,level6', 'True:2,level8', 'True:2,zipCode', 'True:2,customZone', 'True:3,level6', 'True:3,level8', 'True:3,zipCode', 'True:3,customZone', 'True:4,level6', 'True:4,level8', 'True:4,zipCode', 'True:4,customZone', 'True:5,level6', 'True:5,level8', 'True:5,zipCode', 'True:5,customZone', 'True:6,level6', 'True:6,level8', 'True:6,zipCode', 'True:6,customZone', 'True:7,level6', 'True:7,level8', 'True:7,zipCode', 'True:7,customZone', 'True:8,level6', 'True:8,level8', 'True:8,zipCode', 'True:8,customZone', 'True:9,phone_realEstate', 'True:9,level4', 'True:9,level6', 'True:9,zipCode', 'True:9,customZone', 'True:10,level4', 'True:10,level6', 'True:10,zipCode', 'True:10,customZone', 'True:11,level6', 'True:11,level8', 'True:11,zipCode', 'True:11,customZone', 'True:12,level6', 'True:12,level8', 'True:12,zipCode', 'True:12,cust
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
dimensiones = ds.shape
sin_NaN = ds.dropna()
dimensiones_sin_NaN = sin_NaN.shape
print(f"dimensiones originales: {dimensiones}")
print(f"sin NAs: {dimensiones_sin_NaN}")
# Out:
# dimensiones originales: (15335, 37)
# sin NAs: (0, 37)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
media_precios = ds.groupby('level5')['price'].mean()
print(media_precios['Arroyomolinos (Madrid)'])
# Out:
# 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import matplotlib.pyplot as plt
ds_arroyomolinos = ds.loc[ds['level5'] == 'Arroyomolinos (Madrid)']
plt.figure(figsize=(10,5))
plt.hist(ds_arroyomolinos['price'], bins=30, alpha =0.7)
plt.title("histograma precios Arroyomolinos")
plt.show()

# %% [markdown]
# El grueso de los precios en la poblacion de Arroyomolinos (Madrid) se situa entre los 200000 y 400000 EUR

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
print(media_precios['Valdemorillo'],media_precios['Galapagar'])
# Out:
# 363860.2931034483 360063.20238095237

# %% [markdown]
# Si bien el promedio no es exactamente el mismo, la diferencia es lo suficientemente pequeña (en torno al 1%) como para decir que los precios promedio de Valdemorillo y Galapagar son los mismos

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
ds['pps'] = ds['price'] / ds['surface']
media_pps = ds.groupby('level5')['pps'].mean()

print(media_pps['Valdemorillo'],media_pps['Galapagar'])
# Out:
# 1317.9502109024984 1606.3240303094024

# %% [markdown]
# Los promedios de precio por metro cuadrado no son los mismos. Mientras que Valdemorillo tiene un promedio de ~1318, Galapagar tiene un promedio de ~1606. Se puede concluir que la vivienda es más cara en Galapagar ya que aunque el precio promedio de la vivienda es el mismo, una casa con la misma superficie costará más en Galapagar.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
plt.figure(figsize=(10,5))
plt.xlabel('superficie')
plt.ylabel('precio')
plt.ticklabel_format(style='plain')
plt.xlim(0,3000)
plt.scatter(ds['surface'],ds['price'])
plt.title("relacion precio/superficie")
plt.show()

# %% [markdown]
# Aunque no se han depurado los valores extremos del dataset, se aprecia una relacion positiva entre precio y superficie. A medida que aumenta la superficie de las casas aumenta su precio.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
agencias_ds = ds.groupby('realEstate_name').count()
total_agencias = len(agencias_ds)
print(total_agencias)
# Out:
# 1821

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
ds2 = ds
ds2['conteo'] = 0
ds2.fillna(0)
total_poblaciones = ds2.groupby('level5').count()
max_cant_casas = max(total_poblaciones['conteo'])
poblacion_max = total_poblaciones.loc[total_poblaciones['conteo'] == max_cant_casas]

print(list(poblacion_max.index),max_cant_casas)
# Out:
# [' Madrid Capital'] 6643

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
sub_ds = ds.loc[ds['level5'].isin(['Fuenlabrada','Leganés','Getafe','Alcorcón'])]

print(sub_ds)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
cinturon_sur = ['Fuenlabrada','Leganés','Getafe','Alcorcón']
mediana = sub_ds.groupby('level5')['price'].median()
plt.figure(figsize=(10,5))
plt.bar(cinturon_sur, mediana)
plt.title("mediana precios")
plt.show()

# %% [markdown]
# La mediana de precios en Fuenlabrada, Leganés y Alcorcón es similar (etre ~150000 y ~175000), mientras que en Getafe es mayor (~280000).

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
media_sub_ds = sub_ds.groupby('level5')[['price','surface','rooms','bathrooms']].mean()
varianza_sub_ds = sub_ds.groupby('level5')[['price','surface','rooms','bathrooms']].var()

print(media_sub_ds)
print(varianza_sub_ds)
# Out:
#                      price     surface     rooms  bathrooms
# level5
# Alcorcón     230071.052632  105.913295  2.914894   1.623656
# Fuenlabrada  177198.021459  103.624365  3.025974   1.445415
# Getafe       265040.500000  126.896266  3.151724   1.865052
# Leganés      208682.010309  105.852273  2.906736   1.518135
#                     price      surface     rooms  bathrooms
# level5
# Alcorcón     1.594783e+10  4244.323834  0.933895   0.592735
# Fuenlabrada  4.701021e+09  2264.643893  0.355844   0.353367
# Getafe       2.098267e+10  5828.110028  0.772748   0.658809
# Leganés      1.191394e+10  3987.475195  0.824590   0.553055

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
poblacion_cara = sub_ds.groupby('level5')[['address', 'price']].max()
print(poblacion_cara)
# Out:
#                                                        address    price
# level5
# Alcorcón                         Travesia Nuncio del, Alcorcón   950000
# Fuenlabrada  Urbanización Urbanización Parque Miraflores, 5...   490000
# Getafe                                San Sebastián, 1, Getafe  1050000
# Leganés         Plaza Pza España, Gran Oportunidad!!!, Leganés   650000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
Fuenlabrada = sub_ds.loc[ds['level5'].isin(['Fuenlabrada'])]
Fuenlabrada_norm = Fuenlabrada['price'].apply(lambda x: (x-min(Fuenlabrada['price']))/(max(Fuenlabrada['price'])-min(Fuenlabrada['price'])))
Leganes = sub_ds.loc[ds['level5'].isin(['Leganés'])]
Leganes_norm = Leganes['price'].apply(lambda x: (x-min(Leganes['price']))/(max(Leganes['price'])-min(Leganes['price'])))
Getafe = sub_ds.loc[ds['level5'].isin(['Getafe'])]
Getafe_norm = Getafe['price'].apply(lambda x: (x-min(Getafe['price']))/(max(Getafe['price'])-min(Getafe['price'])))
Alcorcon = sub_ds.loc[ds['level5'].isin(['Alcorcón'])]
Alcorcon_norm = Alcorcon['price'].apply(lambda x: (x-min(Alcorcon['price']))/(max(Alcorcon['price'])-min(Alcorcon['price'])))

plt.figure(figsize=(10,5))
plt.hist([Fuenlabrada_norm,Leganes_norm,Getafe_norm,Alcorcon_norm],color=['red','cyan','blue','orange'],label=['Fuenlabrada','Leganes','Getafe','Alcorcon'],stacked=False,bins=20, alpha=0.7)
plt.title("histograma precios cinturon sur")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# La gran mayoría de las casas de las 4 poblaciones tiene un precio inferior al 40% del precio más elevado correspondiente. En el caso de Fuenlabrada Leganés y Alcorcón es incluso inferior al 30%, mientras que en Getafe una cantidad importante de casas oscila entre el 30%-40% del valor máximo.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
datos_pps_Getafe = [f"media: {str(Getafe['pps'].mean())}, mediana: {str(Getafe['pps'].median())}, desviacion_tipica: {str(Getafe['pps'].std())}"]
datos_pps_Alcorcon = [f"media: {str(Alcorcon['pps'].mean())}, mediana: {str(Alcorcon['pps'].median())}, desviacion_tipica: {str(Alcorcon['pps'].std())}"]

print(datos_pps_Getafe)
print(datos_pps_Alcorcon)
# Out:
# ['media: 2066.314949251463, mediana: 1973.3333333333333, desviacion_tipica: 741.8727021510158']
# ['media: 2239.302480199618, mediana: 2207.7922077922076, desviacion_tipica: 539.9515266064398']

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
plt.figure(figsize=(10,5))
plt.subplots_adjust(hspace=0.4, wspace=0.3)
plt.subplot(221)
plt.title('Fuenlabrada')
plt.scatter(Fuenlabrada['surface'],Fuenlabrada[['price']])
plt.subplot(222)
plt.title('Leganes')
plt.scatter(Leganes['surface'],Leganes[['price']])
plt.subplot(223)
plt.title('Getafe')
plt.ticklabel_format(style='plain')
plt.scatter(Getafe['surface'],Getafe[['price']])
plt.subplot(224)
plt.title('Alcorcon')
plt.scatter(Alcorcon['surface'],Alcorcon[['price']])
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
from ipyleaflet import CircleMarker

sub_ds.loc[:, 'latitude'] = sub_ds['latitude'].replace(',', '.', regex=True).astype(float)
sub_ds.loc[:, 'longitude'] = sub_ds['longitude'].replace(',', '.', regex=True).astype(float)
colores = {'Fuenlabrada':'red','Leganés':'blue','Getafe':'green','Alcorcón':'orange'}
coordenadas = sub_ds.groupby('level5')[['latitude', 'longitude']].apply(lambda x: list(zip(x['latitude'], x['longitude']))).to_dict()

for poblacion, coords in coordenadas.items():

    color = colores.get(poblacion, 'gray')

    for lat, lon in coords:
        circle = CircleMarker(location=(lat, lon), radius=1, color=color)
        map.add_layer(circle)
        
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…
